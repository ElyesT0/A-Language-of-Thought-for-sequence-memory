# %%
import numpy as np
import pandas as pd
from modules import *
import scipy.stats as stats
import os

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <h1 style='background-color: #800020; color: white; padding: 10px;'>Load data</h1>

# %%
path_subj = "/Users/elyestabbane/Documents/UNICOG/2-Experiments/complexity_estimation/2-Data/online_exp_data/processed/processed_merged_data.json"
subj_dataset = pd.read_json(path_subj)

# %% [markdown]
# <h1 style='background-color: #800020; color: white; padding: 10px;'>Clean Dataset</h1>

# %%
subj_data_clean, subj_data_clean_with_probes = clean_subj_dataset(subj_dataset)

# %% [markdown]
# <h1 style='background-color: #800020; color: white; padding: 10px;'>Sanity Checks</h1>

# %%
# Sanity check 1 — mean complexity rating per participant for each probe sequence
probe_summary = sanity_check_probe_ratings(subj_data_clean_with_probes)
probe_summary

# %%
# Sanity check 2 — overall rating distribution (non-probe trials)
overall_stats = sanity_check_overall_ratings(subj_data_clean)
overall_stats
